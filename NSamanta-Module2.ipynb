# %% [markdown]
# # Module 2
# Nandini Samanta

# %% [markdown]
# ### Linked List

# %%
# Creating an object Node
# source: https://towardsdatascience.com/python-linked-lists-c3622205da81
class Node:
    def __init__(self, data):
        self.data = data
        self.pointer = None
        self.next = None 
    def set_data(value):
        self.data = value
    def get_data():
        return self.data
    def next_done():
        return self.pointer
    
class LinkedList: 
    def __init__(self,values=None): 
        self.head = None 
        self.tail = None
        
        if values is not None:
            self.insert(values)
    def insert(self, values):
        if self.head is None:
            self.tail=self.head=Node(value)
        else: 
            self.tail.next =Node(value)
            self.tail =self.tail.next
        return self.tail
    
    def size(self):
        count = 0
        node = self.head
        while node: 
            count += 1
            node=node.next
        return count
    # supporting code from https://www.tutorialspoint.com/python_data_structure/python_linked_lists.htm
    def delete_head(self, removekey):
        head_val = self.head 
        
        if (head_val is not None):
            if(head_val.data == removekey):
                self.head = head_val.next
                headval = None
                return 
        while (head_val is not None):
            if (head_val.data == removekey): 
                break 
            prev = head_val
            head_val = head_val.next 
        if (head_val == None):
            return 
        prev.next = head_val.next
            head_val = None

# %% [markdown]
# ### Binary Tree

# %%
# reference code: https://www.geeksforgeeks.org/min-heap-in-python/
# reference code: https://www.geeksforgeeks.org/building-heap-from-array/

import sys 

class Min_heap:
    def __init__(self, n, arr): 
        self.maxsize = 20
        self.size = 0
        self.heap = [0]*(self.maxsize +1)
        self.heap[0] = -1 * sys.maxsize
        self.Front = 1
        
    def parent(self, pos):
        return pos//2
    def left_child(self, pos):
        return 2*pos
    def right_child(self, pos):
        return (2*pos) +1 
    def swap(self, first, second):
        self.heap[first], self.heap[second] = self.heap[second], self.heap[first]
    def heapify(self, arr, pos, n): 
        smallest = i 
        if self.left_child(pos) < n and arr[self.left_child(pos)] > arr[smallest]:
            smallest = self.left_child(pos)
        
        if self.right_child(pos) < n and arr[self.right_child(pos)] > arr[smallest]:
            smallest = self.right_child(pos)
                
        if smallest != i: 
            arr[i], arr[smallest] = arr[smallest], arr[i]
            
            min_heapify(arr, n, smallest)
    def min_heapify(self, arr, n):
        stidx = n //2-1
        
        for i in range(stidx, -1, 1):
            heapify(arr, n, i)
            
    def min_val(self):
        popped = self.heap[self.Front]
        self.heap[self.Front] = self.heap[self.size]
        self.size = self.size -1
        self.min_heapify(self.Front)
        return popped 
    
    def Print(self):
        for i in range(n):
            print(arr[i], end=" ")
        print()
